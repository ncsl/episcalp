# %%
import pandas as pd
from pathlib import Path
import os

# %%
metadata_fpath = Path("D:/ScalpData/JHU-metadata_June2021.csv")
meta = pd.read_csv(metadata_fpath)

# %%
meta
# Out:
#     Record ID First EEG (normal vs abnormal) epileptiform EEG  \
# 0           1                            NaN               No
# 1           2                       abnormal              Yes
# 2           3                            NaN              Yes
# 3           4                            NaN               No
# 4           5                            NaN              Yes
# ..        ...                            ...              ...
# 70         71                         normal               No
# 71         72                         normal               No
# 72         73                         normal               No
# 73         74                         normal               No
# 74         75                       abnormal              Yes
#
#    Type of abnormality  number of AEDs during first eeg Final diagnosis  \
# 0                  NaN                              NaN        epilepsy
# 1                  NaN                              0.0        epilepsy
# 2                  NaN                              1.0        epilepsy
# 3                  NaN                              1.0        epilepsy
# 4                  NaN                              0.0        epilepsy
# ..                 ...                              ...             ...
# 70                 NaN                              1.0            PNES
# 71                 NaN                              1.0        epilepsy
# 72                 NaN                              1.0            PNES
# 73                 NaN                              2.0            PNES
# 74                 NaN                              2.0        epilepsy
#
#    type of epilepsy type of focal epilepsy  location of extra-temporal   \
# 0             focal          extra-temporal                     frontal
# 1               NaN                     NaN                         NaN
# 2       generalized                     NaN                         NaN
# 3             focal          extra-temporal                         NaN
# 4             focal                temporal                         NaN
# ..              ...                     ...                         ...
# 70              NaN                     NaN                         NaN
# 71            focal                temporal                         NaN
# 72              NaN                     NaN                         NaN
# 73              NaN                     NaN                         NaN
# 74            focal                     NaN                         NaN
#
#    date of birth                                  Comments
# 0             NaN                                      NaN
# 1             NaN                                      NaN
# 2             NaN                                      NaN
# 3             NaN                                      NaN
# 4             NaN                                      NaN
# ..            ...                                      ...
# 70      7/28/1975                                      NaN
# 71       6/7/1975                                      NaN
# 72      3/14/1952                                      NaN
# 73            NaN                                      NaN
# 74       6/6/1997  multifocal R>L epilepsy , TPO junction
#
# [75 rows x 11 columns]
