# %% [markdown]
# # Run a Binary/Multiclass Classification Experiment with Cross-Validation
#
# We are interested in extracting which features are necessarily important in the problem of separating out epilepsy from non-epilepsy scalp EEGs. We approach this problem from the lens of a statistical data science problem.
#
# We are given some relatively high-dimensional data over space and time for EEG, and are tasked with determining what properties of the data help a statistical algorithm consistently and robustly predict epilepsy and non-epilepsy.
#
# We can guide the problem's statistics in several ways:
#
#     - engineering of the features, X matrix
#     - engineering of the y labels, y vector
#
# Engineering the X matrix features can involve encoding certain priors of the data. For example, one might assume spatial information is important.
#
# Engineering the y labels can involve different experimental design. Whether that is assuming that epilepsy normal EEGs are similar with epilepsy abnormal EEGs in feature space.
#
# ## To Add New Features
#
# I implemented the `load_derived_datasets` and `get_X_features` functions inside episcalp, which handle loading datasets that are stored in BIDS derivative layout and then transforming those datasets into a feature matrix, X, for input into a classification task.
#
# `Load_derived_datasets` just requires one to define a new reading function similar to how I've done for fragility and tfrs. Spikes are loaded in directly from the raw dataset using `_compute_spike_rates`.
#
# To try different features, one just needs to modify `get_X_features`.

# %%
import numpy as np
import scipy
import scipy.io
import pandas as pd
from pathlib import Path
import os
import collections
from natsort import natsorted
import json
import pickle
import warnings
import sys

from numpy.testing import assert_array_equal

warnings.filterwarnings("ignore")

from sklearn.preprocessing import OrdinalEncoder, LabelBinarizer, LabelEncoder, StandardScaler
from sklearn.dummy import DummyClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.calibration import calibration_curve
from sklearn.metrics import (
    brier_score_loss,
    roc_curve,
    average_precision_score,
    roc_auc_score,
    f1_score,
    recall_score, jaccard_score,
    balanced_accuracy_score,
    accuracy_score,
    auc,precision_score,
    plot_precision_recall_curve,
    average_precision_score,
    precision_recall_curve,
    confusion_matrix,
    cohen_kappa_score, make_scorer
)
from sklearn.inspection import permutation_importance
from sklearn.model_selection import (
    StratifiedGroupKFold,
    cross_validate,
    StratifiedShuffleSplit,
)
from sklearn.utils import resample
from sklearn.pipeline import make_pipeline
import sklearn
from sklearn import preprocessing

import mne
from mne.time_frequency import read_tfrs

mne.set_log_level("ERROR")
from mne_bids import BIDSPath, get_entities_from_fname, get_entity_vals, read_raw_bids

from eztrack.io import read_derivative_npy

sys.path.append("../../")
from episcalp.scripts.spikes.summary import _get_spike_annots
from episcalp.cross_validate import get_X_features, load_derived_datasets, _compute_spike_rates
from episcalp.preprocess.montage import _standard_lobes
from episcalp.utils.utils import NumpyEncoder

# if you installed sporf via README
#from oblique_forests.sporf import ObliqueForestClassifier

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# this should be at least 1.0
print(sklearn.__version__)
# Out:
# 1.1.dev0

# %%
y_enc = LabelEncoder()

# %%
def _get_exp_condition(subject, root):
    part_fname = os.path.join(root, "participants.tsv")
    df = pd.read_csv(part_fname, sep="\t")

    if not subject.startswith("sub-"):
        subject = f"sub-{subject}"

    return df[df["participant_id"] == subject]

# %%
def convert_experimental_cond_to_y(experimental_condition_list):
    """Encoder for y labels."""
    # Group name keys, assigned y-label values
    experimental_condition_map = {
        "non-epilepsy-normal-eeg": 0,
        "epilepsy-normal-eeg": 1,
        "epilepsy-abnormal-eeg": 1,
    }
    return [experimental_condition_map[cond] for cond in experimental_condition_list]

# %% [markdown]
# # Define possible helper functions

# %%
def _preprocess_epochs_tfr(data):
    assert data.ndim == 4

    # take the average over frequencies
    data = np.mean(data, axis=2)

    # move the epoch ("window") axis to last
    data = np.moveaxis(data, 0, -2)

    # compress the time axis
    data = np.mean(data, axis=-1)

    # convert to dB
    data = 20 * np.log10(data)

    data = np.reshape(data, (data.shape[0], -1))
    return data

# %%
def _load_subject_derivs(deriv_path, read_func, subjects=None, ignore_fpaths=None, search_str="*.npy"):
    if subjects is None:
        subjects = get_entity_vals(deriv_path, "subject")

    print(f"Loading data for subjects: {subjects}")
    print(deriv_path)
    
    this_path = deriv_path
    while this_path.parent.name != 'derivatives' and this_path.parent.name != '/':
        this_path = this_path.parent
    root = this_path.parent.parent

    dataset = collections.defaultdict(list)
    for subject in subjects:
        subj_path = deriv_path / f"sub-{subject}"

        # get all files of certain search_str
        fpaths = subj_path.glob(search_str)

        # now load in all file paths
        for fpath in fpaths:
            ignore=False
            for f in ignore_fpaths:
                if f in str(fpath):
                    print(f"Skipping fpath: {fpath}")
                    ignore=True
            if not ignore:
                deriv = read_func(fpath, source_check=False)

                # extract data
                ch_names = deriv.ch_names
                deriv_data = deriv.get_data()

                dataset["subject"].append(subject)
                dataset["data"].append(deriv_data)
                dataset["ch_names"].append(ch_names)
                dataset['roots'].append(root)

    return dataset

# %%
def _load_subject_tfrs(deriv_path, read_func, subjects=None, ignore_fpaths=None, search_str="*.h5"):
    if subjects is None:
        subjects = get_entity_vals(deriv_path, "subject")

    print(f"Loading data for subjects: {subjects}")
    print(deriv_path)
    
    this_path = deriv_path
    while this_path.parent.name != 'derivatives' and this_path.parent.name != '/':
        this_path = this_path.parent
    root = this_path.parent.parent

    dataset = collections.defaultdict(list)
    for subject in subjects:
        subj_path = deriv_path / f"sub-{subject}"

        # get all files of certain search_str
        fpaths = subj_path.glob(search_str)

        # now load in all file paths
        for fpath in fpaths:
            ignore=False
            for f in ignore_fpaths:
                if f in str(fpath):
                    print(f"Skipping fpath: {fpath}")
                    ignore=True
            if not ignore:
                deriv = read_func(fpath)[0]

                # extract data
                ch_names = deriv.ch_names
                deriv_data = deriv.data

                # apply mean across axis 2
                deriv_data = _preprocess_epochs_tfr(deriv_data)
    #             deriv_data = np.mean(deriv_data, axis=2)
                ch_names, deriv_data = removeC3C4(ch_names, deriv_data)
                
                dataset["subject"].append(subject)
                dataset["data"].append(deriv_data)
                dataset["ch_names"].append(ch_names)
                dataset['roots'].append(root)

    return dataset

# %%
def removeC3C4(chnames, data):
    chnames = np.array(chnames)
    data = np.array(data)
    keep_idx = []
    for idx, ch in enumerate(chnames):
        if ch not in ['C3', 'C4']:
            keep_idx.append(idx)
    chnames = chnames[keep_idx]
    data = data[keep_idx, :]
    return chnames, data

# %%
def _load_subject_spikes(root, subjects=None, search_str = "*.edf"):
    if subjects is None:
        subjects = get_entity_vals(root, "subject")

    print(f"Loading data for subjects: {subjects}")

    dataset = collections.defaultdict(list)
    for subject in subjects:
        subj_path = root / f"sub-{subject}"

        # get all files of certain search_str
        fpaths = subj_path.rglob(search_str)

        # now load in all file paths
        for fpath in fpaths:
            entities = get_entities_from_fname(fpath.name)
            bids_path = BIDSPath(root=root, datatype="eeg",
                                extension='.edf', **entities)
            raw = read_raw_bids(bids_path)

            # extract data
            ch_spike_rates = _compute_spike_rates(raw)

            # normalize spike counts
            for ch_name, val in ch_spike_rates.items():
                ch_spike_rates[ch_name] = val / (raw.n_times / raw.info["sfreq"])

            # total spike rate = total # of spikes regardless of channel / times / n_chs
            total_spike_rate = (
                np.sum(list(ch_spike_rates.values()))
                / len(raw.ch_names)
                / (raw.n_times / raw.info["sfreq"])
            )

            # max spike per lobe
            ch_spikes = np.array(list(ch_spike_rates.values()))
            lobe_dict = _standard_lobes(separate_hemispheres=False)

            # value of the max spike rate
            features = np.hstack(
                (
                    ch_spikes.mean(),
                    ch_spikes.std(),
                    np.quantile(ch_spikes, q=0.1),
                    np.quantile(ch_spikes, q=0.5),
                    np.quantile(ch_spikes, q=0.9),
                    total_spike_rate,
                )
            )
            ch_names = raw.ch_names

            assert len(ch_names) == len(ch_spike_rates.keys())
            assert_array_equal(ch_names, list(ch_spike_rates.keys()))

            dataset["data"].append(features)
            dataset["subject"].append(subject)
            dataset["ch_names"].append(ch_names)
            dataset['roots'].append(root)
    return dataset

# %%
def load_spike_results(spike_fpath):
    test_bids_paths = []
    test_proba = []
    with open(spike_fpath.with_suffix(".json"), "r") as fp:
        scores = json.load(fp)
    which_set = "test"
    n_splits = int(spike_fpath.name.split("_")[0].replace("cv",""))
    
    for idx in range(n_splits):
        subs = scores['test_subjects'][idx]
        sess = scores['test_sessions'][idx]
        tasks = scores['test_tasks'][idx]
        runs = scores['test_runs'][idx]
        for sub, ses, task, run in zip(subs, sess, tasks, runs):
            bids_params = {
                "subject": sub,
                "session": ses,
                "task": task,
                "run": run
            }
            bids_path = BIDSPath(**bids_params)
            test_bids_paths.append(bids_path)
        proba = scores['test_y_pred_proba'][idx]
        test_proba.extend(proba)
    return test_bids_paths, test_proba

# %%
def get_abnormal_subjects(bids_paths, y_proba, thresh=0.7):
    abnorm_bidspaths = []
    for bp, y_proba in zip(bids_paths, y_proba):
        if y_proba > thresh:
            abnorm_bidspaths.append(bp.basename)
    return abnorm_bidspaths

# %%
spikes_fpath = Path("D:/OneDriveParent/OneDrive - Johns Hopkins/Scalp_EEG_combined/derivatives/cv10_logreg_mtry6_exp_abnormalspikes_meandiff.json")
test_bidspaths, test_y_proba = load_spike_results(spikes_fpath)
abnorm_bidspaths = get_abnormal_subjects(test_bidspaths, test_y_proba)
abnorm_bidspaths
# Out:
# ['sub-jhh110_run-01',
#  'sub-jeff205_ses-1_run-1',
#  'sub-jeff201_ses-1_run-6',
#  'sub-jhh227_run-01',
#  'sub-jhh214_run-01',
#  'sub-jeff205_ses-1_run-1',
#  'sub-jeff208_ses-1_run-1',
#  'sub-jeff202_ses-1_run-2',
#  'sub-jeff205_ses-1_run-1',
#  'sub-jhh214_run-01',
#  'sub-jeff206_ses-1_run-1',
#  'sub-jhh213_run-01',
#  'sub-jhh216_run-01',
#  'sub-jhh213_run-01',
#  'sub-jhh216_run-01',
#  'sub-jeff206_ses-1_run-1']

# %% [markdown]
# # Define data directories

# %%
user = "patrick"
if user == "patrick":
    jhroot = Path("D:/OneDriveParent/OneDrive - Johns Hopkins/Shared Documents/bids")
    jeffroot = Path("D:/OneDriveParent/Johns Hopkins/Jefferson_Scalp - Documents/root")

    # not ready yet
    upmcroot = Path("/Users/adam2392/Johns Hopkins/UPMC_Scalp - Documents/")
elif user == "adam":
    jhroot = Path("/Users/adam2392/Johns Hopkins/Scalp EEG JHH - Documents/bids/")
    jeffroot = Path("/Users/adam2392/Johns Hopkins/Jefferson_Scalp - Documents/root/")

    # not ready yet
    upmcroot = Path("/Users/adam2392/Johns Hopkins/UPMC_Scalp - Documents/")

# %%
reference = "monopolar"
radius = "1.25"

# define derivative chains
ss_deriv_chain = Path("sourcesink") / reference
frag_deriv_chain = Path("fragility") / f"radius{radius}" / reference

delta_tfr_deriv_chain = Path("tfr") / 'delta'
theta_tfr_deriv_chain = Path("tfr") / 'theta'
alpha_tfr_deriv_chain = Path("tfr") / 'alpha'
beta_tfr_deriv_chain = Path("tfr") / 'beta'

# %%
if user == "adam":
    root = Path("/Users/adam2392/Johns Hopkins/Scalp EEG JHH - Documents/")
elif user == "patrick":
    root = Path("D:/OneDriveParent/OneDrive - Johns Hopkins/Shared Documents/bids")
deriv_root = root / "derivatives"
source_root = root / "sourcedata"

# %% [markdown]
# # Load Feature Spatiotemporal Heatmap Datasets

# %%
exp_name = 'fragilityquantiles_jhhjeff_spikes'

# %%
roots = [jhroot, jeffroot]
deriv_chains = [frag_deriv_chain, frag_deriv_chain]

load_func = _load_subject_derivs
read_func = read_derivative_npy
search_str = '*desc-perturbmatrix*.npy'
kwargs = {
    'subjects': None,
    'ignore_fpaths': abnorm_bidspaths
}

# load fragility dataset
fragility_dataset = load_derived_datasets(roots, deriv_chains=deriv_chains, 
                               load_func=load_func, 
                               read_func=read_func, search_str=search_str, **kwargs)
# Out:
# Loading data for subjects: ['jhh001', 'jhh002', 'jhh003', 'jhh004', 'jhh005', 'jhh006', 'jhh007', 'jhh008', 'jhh009', 'jhh010', 'jhh011', 'jhh012', 'jhh013', 'jhh014', 'jhh015', 'jhh016', 'jhh017', 'jhh018', 'jhh019', 'jhh020', 'jhh021', 'jhh022', 'jhh023', 'jhh024', 'jhh025', 'jhh026', 'jhh027', 'jhh028', 'jhh029', 'jhh030', 'jhh101', 'jhh102', 'jhh103', 'jhh104', 'jhh105', 'jhh106', 'jhh107', 'jhh108', 'jhh109', 'jhh110', 'jhh111', 'jhh112', 'jhh113', 'jhh114', 'jhh115', 'jhh116', 'jhh117', 'jhh118', 'jhh119', 'jhh120', 'jhh121', 'jhh122', 'jhh124', 'jhh125', 'jhh126', 'jhh127', 'jhh128', 'jhh201', 'jhh202', 'jhh203', 'jhh204', 'jhh205', 'jhh206', 'jhh207', 'jhh208', 'jhh209', 'jhh210', 'jhh211', 'jhh212', 'jhh213', 'jhh214', 'jhh215', 'jhh216', 'jhh217', 'jhh218', 'jhh219', 'jhh220', 'jhh221', 'jhh222', 'jhh223', 'jhh224', 'jhh225', 'jhh226', 'jhh227', 'jhh228', 'jhh229']
# D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\fragility\radius1.25\monopolar
# D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\fragility\radius1.25\monopolar\sub-jhh001\sub-jhh001_run-01_desc-perturbmatrix_eeg.json
# D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\fragility\radius1.25\monopolar\sub-jhh002\sub-jhh002_run-01_desc-perturbmatrix_eeg.json
# D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\fragility\radius1.25\monopolar\sub-jhh003\sub-jhh003_run-01_desc-perturbmatrix_eeg.json
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 70, in emit
#     self.doRollover()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 171, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 111, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log' -> 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log.1'
# Call stack:
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\windows_events.py", line 316, in run_forever
#     super().run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 536, in execute_request
#     self.do_execute(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-121-84de695b60ff>", line 13, in <module>
#     fragility_dataset = load_derived_datasets(roots, deriv_chains=deriv_chains,
#   File "d:\desktop\episcalp\episcalp\cross_validate.py", line 85, in load_derived_datasets
#     dataset = load_func(deriv_root, **kwargs)
#   File "<ipython-input-111-8f34e2b60898>", line 28, in _load_subject_derivs
#     deriv = read_func(fpath, source_check=False)
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 250, in read_derivative_npy
#     return DerivativeNumpy(fname, preload, source_check=source_check, verbose=verbose)
#   File "<decorator-gen-18>", line 21, in __init__
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 78, in __init__
#     logger.info("Loading %s" % fname)
# Message: 'Loading D:\\OneDriveParent\\OneDrive - Johns Hopkins\\Shared Documents\\bids\\derivatives\\fragility\\radius1.25\\monopolar\\sub-jhh001\\sub-jhh001_run-01_desc-perturbmatrix_eeg.npy'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 70, in emit
#     self.doRollover()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 171, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 111, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log' -> 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log.1'
# Call stack:
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\windows_events.py", line 316, in run_forever
#     super().run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 536, in execute_request
#     self.do_execute(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-121-84de695b60ff>", line 13, in <module>
#     fragility_dataset = load_derived_datasets(roots, deriv_chains=deriv_chains,
#   File "d:\desktop\episcalp\episcalp\cross_validate.py", line 85, in load_derived_datasets
#     dataset = load_func(deriv_root, **kwargs)
#   File "<ipython-input-111-8f34e2b60898>", line 28, in _load_subject_derivs
#     deriv = read_func(fpath, source_check=False)
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 250, in read_derivative_npy
#     return DerivativeNumpy(fname, preload, source_check=source_check, verbose=verbose)
#   File "<decorator-gen-18>", line 21, in __init__
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 78, in __init__
#     logger.info("Loading %s" % fname)
# Message: 'Loading D:\\OneDriveParent\\OneDrive - Johns Hopkins\\Shared Documents\\bids\\derivatives\\fragility\\radius1.25\\monopolar\\sub-jhh002\\sub-jhh002_run-01_desc-perturbmatrix_eeg.npy'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 70, in emit
#     self.doRollover()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 171, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 111, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log' -> 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log.1'
# Call stack:
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\windows_events.py", line 316, in run_forever
#     super().run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 536, in execute_request
#     self.do_execute(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-121-84de695b60ff>", line 13, in <module>
#     fragility_dataset = load_derived_datasets(roots, deriv_chains=deriv_chains,
#   File "d:\desktop\episcalp\episcalp\cross_validate.py", line 85, in load_derived_datasets
#     dataset = load_func(deriv_root, **kwargs)
#   File "<ipython-input-111-8f34e2b60898>", line 28, in _load_subject_derivs
#     deriv = read_func(fpath, source_check=False)
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 250, in read_derivative_npy
#     return DerivativeNumpy(fname, preload, source_check=source_check, verbose=verbose)
#   File "<decorator-gen-18>", line 21, in __init__
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 78, in __init__
#     logger.info("Loading %s" % fname)
# Message: 'Loading D:\\OneDriveParent\\OneDrive - Johns Hopkins\\Shared Documents\\bids\\derivatives\\fragility\\radius1.25\\monopolar\\sub-jhh003\\sub-jhh003_run-01_desc-perturbmatrix_eeg.npy'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 70, in emit
#     self.doRollover()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 171, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 111, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log' -> 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log.1'
# Call stack:
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\windows_events.py", line 316, in run_forever
#     super().run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 536, in execute_request
#     self.do_execute(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-121-84de695b60ff>", line 13, in <module>
#     fragility_dataset = load_derived_datasets(roots, deriv_chains=deriv_chains,
#   File "d:\desktop\episcalp\episcalp\cross_validate.py", line 85, in load_derived_datasets
#     dataset = load_func(deriv_root, **kwargs)
#   File "<ipython-input-111-8f34e2b60898>", line 28, in _load_subject_derivs
#     deriv = read_func(fpath, source_check=False)
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 250, in read_derivative_npy
#     return DerivativeNumpy(fname, preload, source_check=source_check, verbose=verbose)
#   File "<decorator-gen-18>", line 21, in __init__
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 78, in __init__
#     logger.info("Loading %s" % fname)
# Message: 'Loading D:\\OneDriveParent\\OneDrive - Johns Hopkins\\Shared Documents\\bids\\derivatives\\fragility\\radius1.25\\monopolar\\sub-jhh004\\sub-jhh004_run-01_desc-perturbmatrix_eeg.npy'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 70, in emit
#     self.doRollover()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 171, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 111, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log' -> 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log.1'
# Call stack:
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\windows_events.py", line 316, in run_forever
#     super().run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 536, in execute_request
#     self.do_execute(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-121-84de695b60ff>", line 13, in <module>
#     fragility_dataset = load_derived_datasets(roots, deriv_chains=deriv_chains,
#   File "d:\desktop\episcalp\episcalp\cross_validate.py", line 85, in load_derived_datasets
#     dataset = load_func(deriv_root, **kwargs)
#   File "<ipython-input-111-8f34e2b60898>", line 28, in _load_subject_derivs
#     deriv = read_func(fpath, source_check=False)
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 250, in read_derivative_npy
#     return DerivativeNumpy(fname, preload, source_check=source_check, verbose=verbose)
#   File "<decorator-gen-18>", line 21, in __init__
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 78, in __init__
#     logger.info("Loading %s" % fname)
# Message: 'Loading D:\\OneDriveParent\\OneDrive - Johns Hopkins\\Shared Documents\\bids\\derivatives\\fragility\\radius1.25\\monopolar\\sub-jhh005\\sub-jhh005_run-01_desc-perturbmatrix_eeg.npy'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 70, in emit
#     self.doRollover()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 171, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 111, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log' -> 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log.1'
# Call stack:
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\windows_events.py", line 316, in run_forever
#     super().run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 536, in execute_request
#     self.do_execute(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-121-84de695b60ff>", line 13, in <module>
#     fragility_dataset = load_derived_datasets(roots, deriv_chains=deriv_chains,
#   File "d:\desktop\episcalp\episcalp\cross_validate.py", line 85, in load_derived_datasets
#     dataset = load_func(deriv_root, **kwargs)
#   File "<ipython-input-111-8f34e2b60898>", line 28, in _load_subject_derivs
#     deriv = read_func(fpath, source_check=False)
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 250, in read_derivative_npy
#     return DerivativeNumpy(fname, preload, source_check=source_check, verbose=verbose)
#   File "<decorator-gen-18>", line 21, in __init__
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 78, in __init__
#     logger.info("Loading %s" % fname)
# Message: 'Loading D:\\OneDriveParent\\OneDrive - Johns Hopkins\\Shared Documents\\bids\\derivatives\\fragility\\radius1.25\\monopolar\\sub-jhh006\\sub-jhh006_run-01_desc-perturbmatrix_eeg.npy'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 70, in emit
#     self.doRollover()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 171, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 111, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log' -> 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log.1'
# Call stack:
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\windows_events.py", line 316, in run_forever
#     super().run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 536, in execute_request
#     self.do_execute(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-121-84de695b60ff>", line 13, in <module>
#     fragility_dataset = load_derived_datasets(roots, deriv_chains=deriv_chains,
#   File "d:\desktop\episcalp\episcalp\cross_validate.py", line 85, in load_derived_datasets
#     dataset = load_func(deriv_root, **kwargs)
#   File "<ipython-input-111-8f34e2b60898>", line 28, in _load_subject_derivs
#     deriv = read_func(fpath, source_check=False)
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 250, in read_derivative_npy
#     return DerivativeNumpy(fname, preload, source_check=source_check, verbose=verbose)
#   File "<decorator-gen-18>", line 21, in __init__
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 78, in __init__
#     logger.info("Loading %s" % fname)
# Message: 'Loading D:\\OneDriveParent\\OneDrive - Johns Hopkins\\Shared Documents\\bids\\derivatives\\fragility\\radius1.25\\monopolar\\sub-jhh007\\sub-jhh007_run-01_desc-perturbmatrix_eeg.npy'
# Arguments: ()
# --- Logging error ---
# D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\fragility\radius1.25\monopolar\sub-jhh004\sub-jhh004_run-01_desc-perturbmatrix_eeg.json
# D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\fragility\radius1.25\monopolar\sub-jhh005\sub-jhh005_run-01_desc-perturbmatrix_eeg.json
# D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\fragility\radius1.25\monopolar\sub-jhh006\sub-jhh006_run-01_desc-perturbmatrix_eeg.json
# D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\fragility\radius1.25\monopolar\sub-jhh007\sub-jhh007_run-01_desc-perturbmatrix_eeg.json
# Traceback (most recent call last):
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 70, in emit
#     self.doRollover()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 171, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 111, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log' -> 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log.1'
# Call stack:
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\windows_events.py", line 316, in run_forever
#     super().run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
# ...
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 536, in execute_request
#     self.do_execute(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-121-84de695b60ff>", line 13, in <module>
#     fragility_dataset = load_derived_datasets(roots, deriv_chains=deriv_chains,
#   File "d:\desktop\episcalp\episcalp\cross_validate.py", line 85, in load_derived_datasets
#     dataset = load_func(deriv_root, **kwargs)
#   File "<ipython-input-111-8f34e2b60898>", line 28, in _load_subject_derivs
#     deriv = read_func(fpath, source_check=False)
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 250, in read_derivative_npy
#     return DerivativeNumpy(fname, preload, source_check=source_check, verbose=verbose)
#   File "<decorator-gen-18>", line 21, in __init__
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 78, in __init__
#     logger.info("Loading %s" % fname)
# Message: 'Loading D:\\OneDriveParent\\Johns Hopkins\\Jefferson_Scalp - Documents\\root\\derivatives\\fragility\\radius1.25\\monopolar\\sub-jeff208\\sub-jeff208_ses-2_run-4_desc-perturbmatrix_eeg.npy'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 70, in emit
#     self.doRollover()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 171, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 111, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log' -> 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log.1'
# Call stack:
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\windows_events.py", line 316, in run_forever
#     super().run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 536, in execute_request
#     self.do_execute(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-121-84de695b60ff>", line 13, in <module>
#     fragility_dataset = load_derived_datasets(roots, deriv_chains=deriv_chains,
#   File "d:\desktop\episcalp\episcalp\cross_validate.py", line 85, in load_derived_datasets
#     dataset = load_func(deriv_root, **kwargs)
#   File "<ipython-input-111-8f34e2b60898>", line 28, in _load_subject_derivs
#     deriv = read_func(fpath, source_check=False)
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 250, in read_derivative_npy
#     return DerivativeNumpy(fname, preload, source_check=source_check, verbose=verbose)
#   File "<decorator-gen-18>", line 21, in __init__
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 78, in __init__
#     logger.info("Loading %s" % fname)
# Message: 'Loading D:\\OneDriveParent\\Johns Hopkins\\Jefferson_Scalp - Documents\\root\\derivatives\\fragility\\radius1.25\\monopolar\\sub-jeff209\\sub-jeff209_ses-1_run-1_desc-perturbmatrix_eeg.npy'
# Arguments: ()
# --- Logging error ---
# D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\fragility\radius1.25\monopolar\sub-jeff208\sub-jeff208_ses-1_run-3_desc-perturbmatrix_eeg.json
# D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\fragility\radius1.25\monopolar\sub-jeff208\sub-jeff208_ses-2_run-4_desc-perturbmatrix_eeg.json
# D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\fragility\radius1.25\monopolar\sub-jeff209\sub-jeff209_ses-1_run-1_desc-perturbmatrix_eeg.json
# D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\fragility\radius1.25\monopolar\sub-jeff210\sub-jeff210_ses-1_run-1_desc-perturbmatrix_eeg.json
# Traceback (most recent call last):
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 70, in emit
#     self.doRollover()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 171, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 111, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log' -> 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log.1'
# Call stack:
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\windows_events.py", line 316, in run_forever
#     super().run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 536, in execute_request
#     self.do_execute(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-121-84de695b60ff>", line 13, in <module>
#     fragility_dataset = load_derived_datasets(roots, deriv_chains=deriv_chains,
#   File "d:\desktop\episcalp\episcalp\cross_validate.py", line 85, in load_derived_datasets
#     dataset = load_func(deriv_root, **kwargs)
#   File "<ipython-input-111-8f34e2b60898>", line 28, in _load_subject_derivs
#     deriv = read_func(fpath, source_check=False)
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 250, in read_derivative_npy
#     return DerivativeNumpy(fname, preload, source_check=source_check, verbose=verbose)
#   File "<decorator-gen-18>", line 21, in __init__
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 78, in __init__
#     logger.info("Loading %s" % fname)
# Message: 'Loading D:\\OneDriveParent\\Johns Hopkins\\Jefferson_Scalp - Documents\\root\\derivatives\\fragility\\radius1.25\\monopolar\\sub-jeff210\\sub-jeff210_ses-1_run-1_desc-perturbmatrix_eeg.npy'
# Arguments: ()

# %%
roots = [jhroot, jeffroot]
deriv_chains = [ss_deriv_chain, ss_deriv_chain]

load_func = _load_subject_derivs
read_func = read_derivative_npy
search_str = '*desc-ssindmatrix*.npy'
kwargs = {
    'subjects': None,
    'ignore_fpaths': abnorm_bidspaths
}

# load fragility dataset
sourcesink_dataset = load_derived_datasets(roots, deriv_chains=deriv_chains, 
                               load_func=load_func, 
                               read_func=read_func, search_str=search_str, **kwargs)
# Out:
# Loading data for subjects: ['jhh001', 'jhh002', 'jhh003', 'jhh004', 'jhh005', 'jhh006', 'jhh007', 'jhh008', 'jhh009', 'jhh010', 'jhh011', 'jhh012', 'jhh013', 'jhh014', 'jhh015', 'jhh016', 'jhh017', 'jhh018', 'jhh019', 'jhh020', 'jhh021', 'jhh022', 'jhh023', 'jhh024', 'jhh025', 'jhh026', 'jhh027', 'jhh028', 'jhh029', 'jhh030', 'jhh101', 'jhh102', 'jhh103', 'jhh104', 'jhh105', 'jhh106', 'jhh107', 'jhh108', 'jhh109', 'jhh110', 'jhh111', 'jhh112', 'jhh113', 'jhh114', 'jhh115', 'jhh116', 'jhh117', 'jhh118', 'jhh119', 'jhh120', 'jhh121', 'jhh122', 'jhh124', 'jhh125', 'jhh126', 'jhh127', 'jhh128', 'jhh201', 'jhh202', 'jhh203', 'jhh204', 'jhh205', 'jhh206', 'jhh207', 'jhh208', 'jhh209', 'jhh210', 'jhh211', 'jhh212', 'jhh213', 'jhh214', 'jhh215', 'jhh216', 'jhh217', 'jhh218', 'jhh219', 'jhh220', 'jhh221', 'jhh222', 'jhh223', 'jhh224', 'jhh225', 'jhh226', 'jhh227', 'jhh228', 'jhh229']
# D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\sourcesink\monopolar
# D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\sourcesink\monopolar\sub-jhh001\sub-jhh001_run-01_desc-ssindmatrix_eeg.json
# D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\sourcesink\monopolar\sub-jhh002\sub-jhh002_run-01_desc-ssindmatrix_eeg.json
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 70, in emit
#     self.doRollover()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 171, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 111, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log' -> 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log.1'
# Call stack:
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\windows_events.py", line 316, in run_forever
#     super().run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 536, in execute_request
#     self.do_execute(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-137-b18d926f309b>", line 13, in <module>
#     sourcesink_dataset = load_derived_datasets(roots, deriv_chains=deriv_chains,
#   File "d:\desktop\episcalp\episcalp\cross_validate.py", line 85, in load_derived_datasets
#     dataset = load_func(deriv_root, **kwargs)
#   File "<ipython-input-111-8f34e2b60898>", line 28, in _load_subject_derivs
#     deriv = read_func(fpath, source_check=False)
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 250, in read_derivative_npy
#     return DerivativeNumpy(fname, preload, source_check=source_check, verbose=verbose)
#   File "<decorator-gen-18>", line 21, in __init__
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 78, in __init__
#     logger.info("Loading %s" % fname)
# Message: 'Loading D:\\OneDriveParent\\OneDrive - Johns Hopkins\\Shared Documents\\bids\\derivatives\\sourcesink\\monopolar\\sub-jhh001\\sub-jhh001_run-01_desc-ssindmatrix_eeg.npy'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 70, in emit
#     self.doRollover()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 171, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 111, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log' -> 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log.1'
# Call stack:
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\windows_events.py", line 316, in run_forever
#     super().run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 536, in execute_request
#     self.do_execute(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-137-b18d926f309b>", line 13, in <module>
#     sourcesink_dataset = load_derived_datasets(roots, deriv_chains=deriv_chains,
#   File "d:\desktop\episcalp\episcalp\cross_validate.py", line 85, in load_derived_datasets
#     dataset = load_func(deriv_root, **kwargs)
#   File "<ipython-input-111-8f34e2b60898>", line 28, in _load_subject_derivs
#     deriv = read_func(fpath, source_check=False)
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 250, in read_derivative_npy
#     return DerivativeNumpy(fname, preload, source_check=source_check, verbose=verbose)
#   File "<decorator-gen-18>", line 21, in __init__
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 78, in __init__
#     logger.info("Loading %s" % fname)
# Message: 'Loading D:\\OneDriveParent\\OneDrive - Johns Hopkins\\Shared Documents\\bids\\derivatives\\sourcesink\\monopolar\\sub-jhh002\\sub-jhh002_run-01_desc-ssindmatrix_eeg.npy'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 70, in emit
#     self.doRollover()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 171, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 111, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log' -> 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log.1'
# Call stack:
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\windows_events.py", line 316, in run_forever
#     super().run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 536, in execute_request
#     self.do_execute(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-137-b18d926f309b>", line 13, in <module>
#     sourcesink_dataset = load_derived_datasets(roots, deriv_chains=deriv_chains,
#   File "d:\desktop\episcalp\episcalp\cross_validate.py", line 85, in load_derived_datasets
#     dataset = load_func(deriv_root, **kwargs)
#   File "<ipython-input-111-8f34e2b60898>", line 28, in _load_subject_derivs
#     deriv = read_func(fpath, source_check=False)
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 250, in read_derivative_npy
#     return DerivativeNumpy(fname, preload, source_check=source_check, verbose=verbose)
#   File "<decorator-gen-18>", line 21, in __init__
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 78, in __init__
#     logger.info("Loading %s" % fname)
# Message: 'Loading D:\\OneDriveParent\\OneDrive - Johns Hopkins\\Shared Documents\\bids\\derivatives\\sourcesink\\monopolar\\sub-jhh003\\sub-jhh003_run-01_desc-ssindmatrix_eeg.npy'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 70, in emit
#     self.doRollover()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 171, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 111, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log' -> 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log.1'
# Call stack:
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\windows_events.py", line 316, in run_forever
#     super().run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 536, in execute_request
#     self.do_execute(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-137-b18d926f309b>", line 13, in <module>
#     sourcesink_dataset = load_derived_datasets(roots, deriv_chains=deriv_chains,
#   File "d:\desktop\episcalp\episcalp\cross_validate.py", line 85, in load_derived_datasets
#     dataset = load_func(deriv_root, **kwargs)
#   File "<ipython-input-111-8f34e2b60898>", line 28, in _load_subject_derivs
#     deriv = read_func(fpath, source_check=False)
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 250, in read_derivative_npy
#     return DerivativeNumpy(fname, preload, source_check=source_check, verbose=verbose)
#   File "<decorator-gen-18>", line 21, in __init__
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 78, in __init__
#     logger.info("Loading %s" % fname)
# Message: 'Loading D:\\OneDriveParent\\OneDrive - Johns Hopkins\\Shared Documents\\bids\\derivatives\\sourcesink\\monopolar\\sub-jhh004\\sub-jhh004_run-01_desc-ssindmatrix_eeg.npy'
# Arguments: ()
# D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\sourcesink\monopolar\sub-jhh003\sub-jhh003_run-01_desc-ssindmatrix_eeg.json
# D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\sourcesink\monopolar\sub-jhh004\sub-jhh004_run-01_desc-ssindmatrix_eeg.json
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 70, in emit
#     self.doRollover()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 171, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 111, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log' -> 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log.1'
# Call stack:
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\windows_events.py", line 316, in run_forever
#     super().run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 536, in execute_request
#     self.do_execute(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-137-b18d926f309b>", line 13, in <module>
#     sourcesink_dataset = load_derived_datasets(roots, deriv_chains=deriv_chains,
#   File "d:\desktop\episcalp\episcalp\cross_validate.py", line 85, in load_derived_datasets
#     dataset = load_func(deriv_root, **kwargs)
#   File "<ipython-input-111-8f34e2b60898>", line 28, in _load_subject_derivs
#     deriv = read_func(fpath, source_check=False)
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 250, in read_derivative_npy
#     return DerivativeNumpy(fname, preload, source_check=source_check, verbose=verbose)
#   File "<decorator-gen-18>", line 21, in __init__
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 78, in __init__
#     logger.info("Loading %s" % fname)
# Message: 'Loading D:\\OneDriveParent\\OneDrive - Johns Hopkins\\Shared Documents\\bids\\derivatives\\sourcesink\\monopolar\\sub-jhh005\\sub-jhh005_run-01_desc-ssindmatrix_eeg.npy'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 70, in emit
#     self.doRollover()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 171, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 111, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log' -> 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log.1'
# Call stack:
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\windows_events.py", line 316, in run_forever
#     super().run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 536, in execute_request
#     self.do_execute(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-137-b18d926f309b>", line 13, in <module>
#     sourcesink_dataset = load_derived_datasets(roots, deriv_chains=deriv_chains,
#   File "d:\desktop\episcalp\episcalp\cross_validate.py", line 85, in load_derived_datasets
#     dataset = load_func(deriv_root, **kwargs)
#   File "<ipython-input-111-8f34e2b60898>", line 28, in _load_subject_derivs
#     deriv = read_func(fpath, source_check=False)
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 250, in read_derivative_npy
#     return DerivativeNumpy(fname, preload, source_check=source_check, verbose=verbose)
#   File "<decorator-gen-18>", line 21, in __init__
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 78, in __init__
#     logger.info("Loading %s" % fname)
# Message: 'Loading D:\\OneDriveParent\\OneDrive - Johns Hopkins\\Shared Documents\\bids\\derivatives\\sourcesink\\monopolar\\sub-jhh006\\sub-jhh006_run-01_desc-ssindmatrix_eeg.npy'
# Arguments: ()
# D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\sourcesink\monopolar\sub-jhh005\sub-jhh005_run-01_desc-ssindmatrix_eeg.json
# D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\sourcesink\monopolar\sub-jhh006\sub-jhh006_run-01_desc-ssindmatrix_eeg.json
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 70, in emit
#     self.doRollover()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 171, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 111, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log' -> 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log.1'
# Call stack:
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\windows_events.py", line 316, in run_forever
#     super().run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 536, in execute_request
#     self.do_execute(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-137-b18d926f309b>", line 13, in <module>
#     sourcesink_dataset = load_derived_datasets(roots, deriv_chains=deriv_chains,
#   File "d:\desktop\episcalp\episcalp\cross_validate.py", line 85, in load_derived_datasets
#     dataset = load_func(deriv_root, **kwargs)
#   File "<ipython-input-111-8f34e2b60898>", line 28, in _load_subject_derivs
#     deriv = read_func(fpath, source_check=False)
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 250, in read_derivative_npy
#     return DerivativeNumpy(fname, preload, source_check=source_check, verbose=verbose)
#   File "<decorator-gen-18>", line 21, in __init__
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 78, in __init__
#     logger.info("Loading %s" % fname)
# Message: 'Loading D:\\OneDriveParent\\OneDrive - Johns Hopkins\\Shared Documents\\bids\\derivatives\\sourcesink\\monopolar\\sub-jhh007\\sub-jhh007_run-01_desc-ssindmatrix_eeg.npy'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 70, in emit
#     self.doRollover()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 171, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 111, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log' -> 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log.1'
# Call stack:
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\windows_events.py", line 316, in run_forever
#     super().run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 536, in execute_request
#     self.do_execute(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
# ...
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 536, in execute_request
#     self.do_execute(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-137-b18d926f309b>", line 13, in <module>
#     sourcesink_dataset = load_derived_datasets(roots, deriv_chains=deriv_chains,
#   File "d:\desktop\episcalp\episcalp\cross_validate.py", line 85, in load_derived_datasets
#     dataset = load_func(deriv_root, **kwargs)
#   File "<ipython-input-111-8f34e2b60898>", line 28, in _load_subject_derivs
#     deriv = read_func(fpath, source_check=False)
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 250, in read_derivative_npy
#     return DerivativeNumpy(fname, preload, source_check=source_check, verbose=verbose)
#   File "<decorator-gen-18>", line 21, in __init__
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 78, in __init__
#     logger.info("Loading %s" % fname)
# Message: 'Loading D:\\OneDriveParent\\Johns Hopkins\\Jefferson_Scalp - Documents\\root\\derivatives\\sourcesink\\monopolar\\sub-jeff208\\sub-jeff208_ses-1_run-4_desc-ssindmatrix_eeg.npy'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 70, in emit
#     self.doRollover()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 171, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 111, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log' -> 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log.1'
# Call stack:
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\windows_events.py", line 316, in run_forever
#     super().run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 536, in execute_request
#     self.do_execute(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-137-b18d926f309b>", line 13, in <module>
#     sourcesink_dataset = load_derived_datasets(roots, deriv_chains=deriv_chains,
#   File "d:\desktop\episcalp\episcalp\cross_validate.py", line 85, in load_derived_datasets
#     dataset = load_func(deriv_root, **kwargs)
#   File "<ipython-input-111-8f34e2b60898>", line 28, in _load_subject_derivs
#     deriv = read_func(fpath, source_check=False)
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 250, in read_derivative_npy
#     return DerivativeNumpy(fname, preload, source_check=source_check, verbose=verbose)
#   File "<decorator-gen-18>", line 21, in __init__
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 78, in __init__
#     logger.info("Loading %s" % fname)
# Message: 'Loading D:\\OneDriveParent\\Johns Hopkins\\Jefferson_Scalp - Documents\\root\\derivatives\\sourcesink\\monopolar\\sub-jeff209\\sub-jeff209_ses-1_run-1_desc-ssindmatrix_eeg.npy'
# Arguments: ()
# D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\sourcesink\monopolar\sub-jeff208\sub-jeff208_ses-1_run-3_desc-ssindmatrix_eeg.json
# D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\sourcesink\monopolar\sub-jeff208\sub-jeff208_ses-1_run-4_desc-ssindmatrix_eeg.json
# D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\sourcesink\monopolar\sub-jeff209\sub-jeff209_ses-1_run-1_desc-ssindmatrix_eeg.json
# D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\sourcesink\monopolar\sub-jeff210\sub-jeff210_ses-1_run-1_desc-ssindmatrix_eeg.json
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 70, in emit
#     self.doRollover()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 171, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\logging\handlers.py", line 111, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log' -> 'd:\\desktop\\eztrack\\.eztrack\\logging\\eztrack.log.1'
# Call stack:
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\windows_events.py", line 316, in run_forever
#     super().run_forever()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "c:\users\patri\appdata\local\programs\python\python38\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\kernelbase.py", line 536, in execute_request
#     self.do_execute(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\patri\.virtualenvs\episcalp-235KLvvi\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-137-b18d926f309b>", line 13, in <module>
#     sourcesink_dataset = load_derived_datasets(roots, deriv_chains=deriv_chains,
#   File "d:\desktop\episcalp\episcalp\cross_validate.py", line 85, in load_derived_datasets
#     dataset = load_func(deriv_root, **kwargs)
#   File "<ipython-input-111-8f34e2b60898>", line 28, in _load_subject_derivs
#     deriv = read_func(fpath, source_check=False)
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 250, in read_derivative_npy
#     return DerivativeNumpy(fname, preload, source_check=source_check, verbose=verbose)
#   File "<decorator-gen-18>", line 21, in __init__
#   File "d:\desktop\eztrack\eztrack\io\npy\npy.py", line 78, in __init__
#     logger.info("Loading %s" % fname)
# Message: 'Loading D:\\OneDriveParent\\Johns Hopkins\\Jefferson_Scalp - Documents\\root\\derivatives\\sourcesink\\monopolar\\sub-jeff210\\sub-jeff210_ses-1_run-1_desc-ssindmatrix_eeg.npy'
# Arguments: ()

# %% [markdown]
# ## Load TFR Heatmaps

# %%
roots = [jhroot, jeffroot]
deriv_chains = [delta_tfr_deriv_chain, delta_tfr_deriv_chain]

load_func = _load_subject_tfrs
read_func = read_tfrs
search_str = '*.h5'
kwargs = {
    'subjects': None,
    'ignore_fpaths': abnorm_bidspaths
}

# load fragility dataset
delta_dataset = load_derived_datasets(roots, deriv_chains=deriv_chains, 
                               load_func=load_func, 
                               read_func=read_func, search_str=search_str, **kwargs)
# Out:
# Loading data for subjects: ['jhh001', 'jhh002', 'jhh003', 'jhh004', 'jhh005', 'jhh006', 'jhh007', 'jhh008', 'jhh009', 'jhh010', 'jhh011', 'jhh012', 'jhh013', 'jhh014', 'jhh015', 'jhh016', 'jhh017', 'jhh018', 'jhh019', 'jhh020', 'jhh021', 'jhh022', 'jhh023', 'jhh024', 'jhh025', 'jhh026', 'jhh027', 'jhh028', 'jhh029', 'jhh030', 'jhh101', 'jhh102', 'jhh103', 'jhh104', 'jhh105', 'jhh106', 'jhh107', 'jhh108', 'jhh109', 'jhh110', 'jhh111', 'jhh112', 'jhh113', 'jhh114', 'jhh115', 'jhh116', 'jhh117', 'jhh118', 'jhh119', 'jhh120', 'jhh121', 'jhh122', 'jhh124', 'jhh125', 'jhh126', 'jhh127', 'jhh128', 'jhh201', 'jhh202', 'jhh203', 'jhh204', 'jhh205', 'jhh206', 'jhh207', 'jhh208', 'jhh209', 'jhh210', 'jhh211', 'jhh212', 'jhh213', 'jhh214', 'jhh215', 'jhh216', 'jhh217', 'jhh218', 'jhh219', 'jhh220', 'jhh221', 'jhh222', 'jhh223', 'jhh224', 'jhh225', 'jhh226', 'jhh227', 'jhh228', 'jhh229']
# D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\delta
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\delta\sub-jhh110\sub-jhh110_run-01_desc-delta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\delta\sub-jhh213\sub-jhh213_run-01_desc-delta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\delta\sub-jhh213\sub-jhh213_run-01_desc-delta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\delta\sub-jhh214\sub-jhh214_run-01_desc-delta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\delta\sub-jhh214\sub-jhh214_run-01_desc-delta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\delta\sub-jhh216\sub-jhh216_run-01_desc-delta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\delta\sub-jhh216\sub-jhh216_run-01_desc-delta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\delta\sub-jhh227\sub-jhh227_run-01_desc-delta_eeg-tfr.h5
# Loading data for subjects: ['jeff001', 'jeff002', 'jeff101', 'jeff102', 'jeff201', 'jeff202', 'jeff203', 'jeff204', 'jeff205', 'jeff206', 'jeff207', 'jeff208', 'jeff209', 'jeff210']
# D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\delta
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\delta\sub-jeff201\sub-jeff201_ses-1_run-6_desc-delta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\delta\sub-jeff202\sub-jeff202_ses-1_run-2_desc-delta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\delta\sub-jeff205\sub-jeff205_ses-1_run-1_desc-delta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\delta\sub-jeff205\sub-jeff205_ses-1_run-1_desc-delta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\delta\sub-jeff205\sub-jeff205_ses-1_run-1_desc-delta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\delta\sub-jeff206\sub-jeff206_ses-1_run-1_desc-delta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\delta\sub-jeff206\sub-jeff206_ses-1_run-1_desc-delta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\delta\sub-jeff208\sub-jeff208_ses-1_run-1_desc-delta_eeg-tfr.h5

# %%
roots = [jhroot, jeffroot]
deriv_chains = [theta_tfr_deriv_chain, theta_tfr_deriv_chain]

load_func = _load_subject_tfrs
read_func = read_tfrs
search_str = '*.h5'
kwargs = {
    'subjects': None,
    'ignore_fpaths': abnorm_bidspaths
}

# load fragility dataset
theta_dataset = load_derived_datasets(roots, deriv_chains=deriv_chains, 
                               load_func=load_func, 
                               read_func=read_func, search_str=search_str, **kwargs)
# Out:
# Loading data for subjects: ['jhh001', 'jhh002', 'jhh003', 'jhh004', 'jhh005', 'jhh006', 'jhh007', 'jhh008', 'jhh009', 'jhh010', 'jhh011', 'jhh012', 'jhh013', 'jhh014', 'jhh015', 'jhh016', 'jhh017', 'jhh018', 'jhh019', 'jhh020', 'jhh021', 'jhh022', 'jhh023', 'jhh024', 'jhh025', 'jhh026', 'jhh027', 'jhh028', 'jhh029', 'jhh030', 'jhh101', 'jhh102', 'jhh103', 'jhh104', 'jhh105', 'jhh106', 'jhh107', 'jhh108', 'jhh109', 'jhh110', 'jhh111', 'jhh112', 'jhh113', 'jhh114', 'jhh115', 'jhh116', 'jhh117', 'jhh118', 'jhh119', 'jhh120', 'jhh121', 'jhh122', 'jhh124', 'jhh125', 'jhh126', 'jhh127', 'jhh128', 'jhh201', 'jhh202', 'jhh203', 'jhh204', 'jhh205', 'jhh206', 'jhh207', 'jhh208', 'jhh209', 'jhh210', 'jhh211', 'jhh212', 'jhh213', 'jhh214', 'jhh215', 'jhh216', 'jhh217', 'jhh218', 'jhh219', 'jhh220', 'jhh221', 'jhh222', 'jhh223', 'jhh224', 'jhh225', 'jhh226', 'jhh227', 'jhh228', 'jhh229']
# D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\theta
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\theta\sub-jhh110\sub-jhh110_run-01_desc-theta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\theta\sub-jhh213\sub-jhh213_run-01_desc-theta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\theta\sub-jhh213\sub-jhh213_run-01_desc-theta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\theta\sub-jhh214\sub-jhh214_run-01_desc-theta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\theta\sub-jhh214\sub-jhh214_run-01_desc-theta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\theta\sub-jhh216\sub-jhh216_run-01_desc-theta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\theta\sub-jhh216\sub-jhh216_run-01_desc-theta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\theta\sub-jhh227\sub-jhh227_run-01_desc-theta_eeg-tfr.h5
# Loading data for subjects: ['jeff001', 'jeff002', 'jeff101', 'jeff102', 'jeff201', 'jeff202', 'jeff203', 'jeff204', 'jeff205', 'jeff206', 'jeff207', 'jeff208', 'jeff209', 'jeff210']
# D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\theta
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\theta\sub-jeff201\sub-jeff201_ses-1_run-6_desc-theta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\theta\sub-jeff202\sub-jeff202_ses-1_run-2_desc-theta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\theta\sub-jeff205\sub-jeff205_ses-1_run-1_desc-theta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\theta\sub-jeff205\sub-jeff205_ses-1_run-1_desc-theta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\theta\sub-jeff205\sub-jeff205_ses-1_run-1_desc-theta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\theta\sub-jeff206\sub-jeff206_ses-1_run-1_desc-theta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\theta\sub-jeff206\sub-jeff206_ses-1_run-1_desc-theta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\theta\sub-jeff208\sub-jeff208_ses-1_run-1_desc-theta_eeg-tfr.h5

# %%
roots = [jhroot, jeffroot]
deriv_chains = [alpha_tfr_deriv_chain, alpha_tfr_deriv_chain]

load_func = _load_subject_tfrs
read_func = read_tfrs
search_str = '*.h5'
kwargs = {
    'subjects': None,
    'ignore_fpaths': abnorm_bidspaths
}

# load fragility dataset
alpha_dataset = load_derived_datasets(roots, deriv_chains=deriv_chains, 
                               load_func=load_func, 
                               read_func=read_func, search_str=search_str, **kwargs)
# Out:
# Loading data for subjects: ['jhh001', 'jhh002', 'jhh003', 'jhh004', 'jhh005', 'jhh006', 'jhh007', 'jhh008', 'jhh009', 'jhh010', 'jhh011', 'jhh012', 'jhh013', 'jhh014', 'jhh015', 'jhh016', 'jhh017', 'jhh018', 'jhh019', 'jhh020', 'jhh021', 'jhh022', 'jhh023', 'jhh024', 'jhh025', 'jhh026', 'jhh027', 'jhh028', 'jhh029', 'jhh030', 'jhh101', 'jhh102', 'jhh103', 'jhh104', 'jhh105', 'jhh106', 'jhh107', 'jhh108', 'jhh109', 'jhh110', 'jhh111', 'jhh112', 'jhh113', 'jhh114', 'jhh115', 'jhh116', 'jhh117', 'jhh118', 'jhh119', 'jhh120', 'jhh121', 'jhh122', 'jhh124', 'jhh125', 'jhh126', 'jhh127', 'jhh128', 'jhh201', 'jhh202', 'jhh203', 'jhh204', 'jhh205', 'jhh206', 'jhh207', 'jhh208', 'jhh209', 'jhh210', 'jhh211', 'jhh212', 'jhh213', 'jhh214', 'jhh215', 'jhh216', 'jhh217', 'jhh218', 'jhh219', 'jhh220', 'jhh221', 'jhh222', 'jhh223', 'jhh224', 'jhh225', 'jhh226', 'jhh227', 'jhh228', 'jhh229']
# D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\alpha
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\alpha\sub-jhh110\sub-jhh110_run-01_desc-alpha_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\alpha\sub-jhh213\sub-jhh213_run-01_desc-alpha_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\alpha\sub-jhh213\sub-jhh213_run-01_desc-alpha_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\alpha\sub-jhh214\sub-jhh214_run-01_desc-alpha_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\alpha\sub-jhh214\sub-jhh214_run-01_desc-alpha_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\alpha\sub-jhh216\sub-jhh216_run-01_desc-alpha_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\alpha\sub-jhh216\sub-jhh216_run-01_desc-alpha_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\alpha\sub-jhh227\sub-jhh227_run-01_desc-alpha_eeg-tfr.h5
# Loading data for subjects: ['jeff001', 'jeff002', 'jeff101', 'jeff102', 'jeff201', 'jeff202', 'jeff203', 'jeff204', 'jeff205', 'jeff206', 'jeff207', 'jeff208', 'jeff209', 'jeff210']
# D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\alpha
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\alpha\sub-jeff201\sub-jeff201_ses-1_run-6_desc-alpha_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\alpha\sub-jeff202\sub-jeff202_ses-1_run-2_desc-alpha_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\alpha\sub-jeff205\sub-jeff205_ses-1_run-1_desc-alpha_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\alpha\sub-jeff205\sub-jeff205_ses-1_run-1_desc-alpha_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\alpha\sub-jeff205\sub-jeff205_ses-1_run-1_desc-alpha_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\alpha\sub-jeff206\sub-jeff206_ses-1_run-1_desc-alpha_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\alpha\sub-jeff206\sub-jeff206_ses-1_run-1_desc-alpha_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\alpha\sub-jeff208\sub-jeff208_ses-1_run-1_desc-alpha_eeg-tfr.h5

# %%
roots = [jhroot, jeffroot]
deriv_chains = [beta_tfr_deriv_chain, beta_tfr_deriv_chain]

load_func = _load_subject_tfrs
read_func = read_tfrs
search_str = '*.h5'
kwargs = {
    'subjects': None,
    'ignore_fpaths': abnorm_bidspaths
}

# load fragility dataset
beta_dataset = load_derived_datasets(roots, deriv_chains=deriv_chains, 
                               load_func=load_func, 
                               read_func=read_func, search_str=search_str, **kwargs)
# Out:
# Loading data for subjects: ['jhh001', 'jhh002', 'jhh003', 'jhh004', 'jhh005', 'jhh006', 'jhh007', 'jhh008', 'jhh009', 'jhh010', 'jhh011', 'jhh012', 'jhh013', 'jhh014', 'jhh015', 'jhh016', 'jhh017', 'jhh018', 'jhh019', 'jhh020', 'jhh021', 'jhh022', 'jhh023', 'jhh024', 'jhh025', 'jhh026', 'jhh027', 'jhh028', 'jhh029', 'jhh030', 'jhh101', 'jhh102', 'jhh103', 'jhh104', 'jhh105', 'jhh106', 'jhh107', 'jhh108', 'jhh109', 'jhh110', 'jhh111', 'jhh112', 'jhh113', 'jhh114', 'jhh115', 'jhh116', 'jhh117', 'jhh118', 'jhh119', 'jhh120', 'jhh121', 'jhh122', 'jhh124', 'jhh125', 'jhh126', 'jhh127', 'jhh128', 'jhh201', 'jhh202', 'jhh203', 'jhh204', 'jhh205', 'jhh206', 'jhh207', 'jhh208', 'jhh209', 'jhh210', 'jhh211', 'jhh212', 'jhh213', 'jhh214', 'jhh215', 'jhh216', 'jhh217', 'jhh218', 'jhh219', 'jhh220', 'jhh221', 'jhh222', 'jhh223', 'jhh224', 'jhh225', 'jhh226', 'jhh227', 'jhh228', 'jhh229']
# D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\beta
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\beta\sub-jhh110\sub-jhh110_run-01_desc-beta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\beta\sub-jhh213\sub-jhh213_run-01_desc-beta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\beta\sub-jhh213\sub-jhh213_run-01_desc-beta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\beta\sub-jhh214\sub-jhh214_run-01_desc-beta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\beta\sub-jhh214\sub-jhh214_run-01_desc-beta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\beta\sub-jhh216\sub-jhh216_run-01_desc-beta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\beta\sub-jhh216\sub-jhh216_run-01_desc-beta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\tfr\beta\sub-jhh227\sub-jhh227_run-01_desc-beta_eeg-tfr.h5
# Loading data for subjects: ['jeff001', 'jeff002', 'jeff101', 'jeff102', 'jeff201', 'jeff202', 'jeff203', 'jeff204', 'jeff205', 'jeff206', 'jeff207', 'jeff208', 'jeff209', 'jeff210']
# D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\beta
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\beta\sub-jeff201\sub-jeff201_ses-1_run-6_desc-beta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\beta\sub-jeff202\sub-jeff202_ses-1_run-2_desc-beta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\beta\sub-jeff205\sub-jeff205_ses-1_run-1_desc-beta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\beta\sub-jeff205\sub-jeff205_ses-1_run-1_desc-beta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\beta\sub-jeff205\sub-jeff205_ses-1_run-1_desc-beta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\beta\sub-jeff206\sub-jeff206_ses-1_run-1_desc-beta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\beta\sub-jeff206\sub-jeff206_ses-1_run-1_desc-beta_eeg-tfr.h5
# Skipping fpath: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\derivatives\tfr\beta\sub-jeff208\sub-jeff208_ses-1_run-1_desc-beta_eeg-tfr.h5

# %% [markdown]
# ## Load Spikes

# %%
def _convert_list_to_collection(deriv_dataset):
    # convert to a dictionary of lists
    derived_dataset = {key: [] for key in deriv_dataset[0].keys()}
    for deriv in deriv_dataset:
        for key in derived_dataset.keys():
            derived_dataset[key].extend(deriv[key])

    return derived_dataset

dataset_list = []
for root in roots:
    print('Getting spikes for', root)
    spike_dataset = _load_subject_spikes(root)
    dataset_list.append(spike_dataset)

print('Done...')
spikes_dataset = _convert_list_to_collection(dataset_list)
# Out:
# Getting spikes for D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids
# Loading data for subjects: ['jhh001', 'jhh002', 'jhh003', 'jhh004', 'jhh005', 'jhh006', 'jhh007', 'jhh008', 'jhh009', 'jhh010', 'jhh011', 'jhh012', 'jhh013', 'jhh014', 'jhh015', 'jhh016', 'jhh017', 'jhh018', 'jhh019', 'jhh020', 'jhh021', 'jhh022', 'jhh023', 'jhh024', 'jhh025', 'jhh026', 'jhh027', 'jhh028', 'jhh029', 'jhh030', 'jhh101', 'jhh102', 'jhh103', 'jhh104', 'jhh105', 'jhh106', 'jhh107', 'jhh108', 'jhh109', 'jhh110', 'jhh111', 'jhh112', 'jhh113', 'jhh114', 'jhh115', 'jhh116', 'jhh117', 'jhh118', 'jhh119', 'jhh120', 'jhh121', 'jhh122', 'jhh124', 'jhh125', 'jhh126', 'jhh127', 'jhh128', 'jhh201', 'jhh202', 'jhh203', 'jhh204', 'jhh205', 'jhh206', 'jhh207', 'jhh208', 'jhh209', 'jhh210', 'jhh211', 'jhh212', 'jhh213', 'jhh214', 'jhh215', 'jhh216', 'jhh217', 'jhh218', 'jhh219', 'jhh220', 'jhh221', 'jhh222', 'jhh223', 'jhh224', 'jhh225', 'jhh226', 'jhh227', 'jhh228', 'jhh229']
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh001\eeg\sub-jhh001_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh002\eeg\sub-jhh002_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh003\eeg\sub-jhh003_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh004\eeg\sub-jhh004_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh005\eeg\sub-jhh005_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh006\eeg\sub-jhh006_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh007\eeg\sub-jhh007_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh008\eeg\sub-jhh008_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh009\eeg\sub-jhh009_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh010\eeg\sub-jhh010_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh011\eeg\sub-jhh011_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh012\eeg\sub-jhh012_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh013\eeg\sub-jhh013_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh014\eeg\sub-jhh014_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh015\eeg\sub-jhh015_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh016\eeg\sub-jhh016_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh017\eeg\sub-jhh017_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh018\eeg\sub-jhh018_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh019\eeg\sub-jhh019_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh020\eeg\sub-jhh020_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh021\eeg\sub-jhh021_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh022\eeg\sub-jhh022_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh023\eeg\sub-jhh023_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh024\eeg\sub-jhh024_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh025\eeg\sub-jhh025_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh026\eeg\sub-jhh026_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh027\eeg\sub-jhh027_task-asleep_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh027\eeg\sub-jhh027_task-awake_run-02_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh028\eeg\sub-jhh028_task-asleep_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh028\eeg\sub-jhh028_task-awake_run-02_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh029\eeg\sub-jhh029_task-awake_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh030\eeg\sub-jhh030_task-awake_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh101\eeg\sub-jhh101_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh102\eeg\sub-jhh102_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh103\eeg\sub-jhh103_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh104\eeg\sub-jhh104_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh105\eeg\sub-jhh105_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh106\eeg\sub-jhh106_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh107\eeg\sub-jhh107_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh108\eeg\sub-jhh108_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh109\eeg\sub-jhh109_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh110\eeg\sub-jhh110_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh111\eeg\sub-jhh111_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh112\eeg\sub-jhh112_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh113\eeg\sub-jhh113_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh114\eeg\sub-jhh114_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh115\eeg\sub-jhh115_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh116\eeg\sub-jhh116_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh117\eeg\sub-jhh117_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh118\eeg\sub-jhh118_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh119\eeg\sub-jhh119_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh120\eeg\sub-jhh120_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh121\eeg\sub-jhh121_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh122\eeg\sub-jhh122_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh124\eeg\sub-jhh124_task-asleep_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh124\eeg\sub-jhh124_task-awake_run-02_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh125\eeg\sub-jhh125_task-asleep_run-02_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh125\eeg\sub-jhh125_task-awake_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh126\eeg\sub-jhh126_task-awake_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh127\eeg\sub-jhh127_task-asleep_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh127\eeg\sub-jhh127_task-awake_run-02_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh128\eeg\sub-jhh128_task-awake_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh201\eeg\sub-jhh201_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh202\eeg\sub-jhh202_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh203\eeg\sub-jhh203_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh204\eeg\sub-jhh204_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh205\eeg\sub-jhh205_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh206\eeg\sub-jhh206_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh207\eeg\sub-jhh207_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh208\eeg\sub-jhh208_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh209\eeg\sub-jhh209_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh210\eeg\sub-jhh210_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh211\eeg\sub-jhh211_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh212\eeg\sub-jhh212_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh213\eeg\sub-jhh213_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh214\eeg\sub-jhh214_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh215\eeg\sub-jhh215_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh216\eeg\sub-jhh216_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh217\eeg\sub-jhh217_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh218\eeg\sub-jhh218_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh219\eeg\sub-jhh219_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh220\eeg\sub-jhh220_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh221\eeg\sub-jhh221_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh222\eeg\sub-jhh222_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh223\eeg\sub-jhh223_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh224\eeg\sub-jhh224_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh225\eeg\sub-jhh225_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh226\eeg\sub-jhh226_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh227\eeg\sub-jhh227_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh228\eeg\sub-jhh228_task-asleep_run-01_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh228\eeg\sub-jhh228_task-awake_run-02_events.tsv
# Events fname: D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\sub-jhh229\eeg\sub-jhh229_task-awake_run-01_events.tsv
# Getting spikes for D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root
# Loading data for subjects: ['jeff001', 'jeff002', 'jeff101', 'jeff102', 'jeff201', 'jeff202', 'jeff203', 'jeff204', 'jeff205', 'jeff206', 'jeff207', 'jeff208', 'jeff209', 'jeff210']
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff001\ses-1\eeg\sub-jeff001_ses-1_run-1_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff001\ses-1\eeg\sub-jeff001_ses-1_run-2_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff002\ses-1\eeg\sub-jeff002_ses-1_run-1_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff101\ses-1\eeg\sub-jeff101_ses-1_run-2_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff101\ses-1\eeg\sub-jeff101_ses-1_run-4_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff102\ses-1\eeg\sub-jeff102_ses-1_run-1_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff102\ses-1\eeg\sub-jeff102_ses-1_run-2_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff102\ses-1\eeg\sub-jeff102_ses-1_run-3_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff102\ses-1\eeg\sub-jeff102_ses-1_run-4_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff102\ses-1\eeg\sub-jeff102_ses-1_run-5_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff201\ses-1\eeg\sub-jeff201_ses-1_run-1_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff201\ses-1\eeg\sub-jeff201_ses-1_run-2_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff201\ses-1\eeg\sub-jeff201_ses-1_run-3_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff201\ses-1\eeg\sub-jeff201_ses-1_run-4_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff201\ses-1\eeg\sub-jeff201_ses-1_run-5_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff201\ses-1\eeg\sub-jeff201_ses-1_run-6_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff202\ses-1\eeg\sub-jeff202_ses-1_run-1_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff202\ses-1\eeg\sub-jeff202_ses-1_run-2_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff202\ses-1\eeg\sub-jeff202_ses-1_run-3_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff202\ses-1\eeg\sub-jeff202_ses-1_run-4_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff202\ses-1\eeg\sub-jeff202_ses-1_run-5_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff203\ses-1\eeg\sub-jeff203_ses-1_run-1_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff203\ses-1\eeg\sub-jeff203_ses-1_run-3_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff204\ses-1\eeg\sub-jeff204_ses-1_run-1_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff205\ses-1\eeg\sub-jeff205_ses-1_run-1_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff206\ses-1\eeg\sub-jeff206_ses-1_run-1_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff207\ses-1\eeg\sub-jeff207_ses-1_run-1_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff208\ses-1\eeg\sub-jeff208_ses-1_run-1_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff208\ses-1\eeg\sub-jeff208_ses-1_run-2_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff208\ses-1\eeg\sub-jeff208_ses-1_run-3_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff208\ses-2\eeg\sub-jeff208_ses-2_run-4_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff209\ses-1\eeg\sub-jeff209_ses-1_run-1_events.tsv
# Events fname: D:\OneDriveParent\Johns Hopkins\Jefferson_Scalp - Documents\root\sub-jeff210\ses-1\eeg\sub-jeff210_ses-1_run-1_events.tsv
# Done...

# %%
X_spikes = np.array(spikes_dataset['data'])
print(X_spikes.shape)
# Out:
# (125, 6)

# %% [markdown]
# # Convert Spatiotemporal Datasets Into Feature Matrix

# %%
X = get_X_features(fragility_dataset, feature_name='data')

print(X.shape)

sns.heatmap(X)
# Out:
# (115, 5)
# <AxesSubplot:>

# %%
dataset = beta_dataset

X = get_X_features(dataset, feature_name='data')
# get the y-labels 
subjects = np.array(dataset['subject'])
roots = dataset['roots']

exp_conditions = []
for subject, root in zip(subjects, roots):
    subj_df = _get_exp_condition(subject, root)
    exp_condition = subj_df["exp_condition"].values[0]
    exp_conditions.append(exp_condition)
print(np.unique(exp_conditions))
# Out:
# ['epilepsy-abnormal-eeg' 'epilepsy-normal-eeg' 'non-epilepsy-normal-eeg']

# %%
y = y_enc.fit_transform(exp_conditions)
y_classes = y_enc.classes_
print(y_enc.classes_)
# Out:
# ['epilepsy-abnormal-eeg' 'epilepsy-normal-eeg' 'non-epilepsy-normal-eeg']

# %%
y = convert_experimental_cond_to_y(exp_conditions)
y = np.array(y)

# %%
from numpy.testing import assert_array_equal

for ch_names_ in dataset['ch_names']:
    assert_array_equal(ch_names, ch_names_)

print(ch_names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-b57443d4c083> in <module>
#       2
#       3 for ch_names_ in dataset['ch_names']:
# ----> 4     assert_array_equal(ch_names, ch_names_)
#       5
#       6 print(ch_names)
#
# NameError: name 'ch_names' is not defined

# %% [markdown]
# # Define Cross Validation Experiment

# %%
n_splits = 20
train_size = 0.7
random_state = 12345

# %%
cv = StratifiedGroupKFold(
    n_splits=n_splits,
    random_state=random_state,
    shuffle=True,
)
cv = StratifiedShuffleSplit(
    n_splits=n_splits,
    train_size=train_size,
    random_state=random_state,
)

# %% [markdown]
# ## Define Classification Models

# %%
random_state = 12345
#clf_name = "sporf"
clf_name = 'lr'
max_features = X.shape[1]

rf_model_params = {
    "n_estimators": 1000,
    "max_features": max_features,
    "n_jobs": -1,
    "random_state": random_state,
}
lr_model_params = {"n_jobs": -1, "random_state": random_state}

# %%
if clf_name == "rf":
    clf = RandomForestClassifier(**rf_model_params)
elif clf_name == "sporf":
    # only used if you installed cysporf
    clf = ObliqueForestClassifier(**rf_model_params)
elif clf_name == "lr":
    clf = LogisticRegression(**lr_model_params)

# %% [markdown]
# # Run sklearn.cross_validate

# %%
clf = make_pipeline(StandardScaler(), clf)
print(X.shape, y.shape)
print(clf)
# Out:
# (115, 5) (115,)
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(n_jobs=-1, random_state=12345))])

# %%
scoring_funcs = {
    'balanced_accuracy': make_scorer(balanced_accuracy_score),
    'cohen_kappa_score': make_scorer(cohen_kappa_score),
    'roc_auc': 'roc_auc', #roc_auc_score,
    'f1': 'f1', #f1_score,
    'recall': make_scorer(recall_score),
    'precision': make_scorer(precision_score),
    'jaccard': make_scorer(jaccard_score),
    'average_precision': make_scorer(average_precision_score),
    'neg_brier_score': make_scorer(brier_score_loss),
}

# define multiclass cross_validation scoring metrics
f1_micro = lambda x : make_scorer(f1_score, average='micro')
recall_micro = lambda x : make_scorer(recall_score, average='micro')
precision_micro = lambda x: make_scorer(precision_score, average='micro')
jaccard_micro = lambda x: make_scorer(jaccard_score, average='micro')
roc_ovr = lambda x: make_scorer(roc_auc_score, multi_class='ovr')
multiclass_scoring_funcs = {
    'balanced_accuracy': make_scorer(balanced_accuracy_score),
    'cohen_kappa_score': make_scorer(cohen_kappa_score),
    'roc_auc_ovr': 'roc_auc_ovr',# roc_ovr,
    'f1_micro': 'f1_micro', #f1_micro,
    'recall_micro': 'recall_micro',
    'precision_micro': 'precision_micro',
    'jaccard_micro': 'jaccard_micro',
}

if len(np.unique(y)) == 2:
    scoring = scoring_funcs
else:
    scoring = multiclass_scoring_funcs
    
print(scoring)
# Out:
# {'balanced_accuracy': make_scorer(balanced_accuracy_score), 'cohen_kappa_score': make_scorer(cohen_kappa_score), 'roc_auc': 'roc_auc', 'f1': 'f1', 'recall': make_scorer(recall_score), 'precision': make_scorer(precision_score), 'jaccard': make_scorer(jaccard_score), 'average_precision': make_scorer(average_precision_score), 'neg_brier_score': make_scorer(brier_score_loss)}

# %%
# run cross-validation
scores = cross_validate(
    clf,
    X,
    y,
    groups=subjects,
    cv=cv,
    scoring=scoring,
    return_estimator=True,
    return_train_score=True,
    n_jobs=-1,
)

# get the estimators
estimators = scores.pop("estimator")

# %%
print("Using estimator ", estimators[0])

# initialize keys to list
for key in [
    "test_fraction_pos",
    "test_mean_pred_value",
    "test_fpr",
    "test_tpr",
    "test_fnr",
    "test_tnr",
    "test_thresholds",
    "train_fraction_pos",
    "train_mean_pred_value",
    "train_y_pred_proba",
    "train_fpr",
    "train_tpr",
    "train_fnr",
    "train_tnr",
    "train_thresholds",
    "train_subjects",
    "test_subjects",
    "test_y_pred_proba",
    "test_importances",
    "test_specificity",
    "test_y",
    "test_y_encodings",
]:
    scores[key] = []

for idx, (train_inds, test_inds) in enumerate(cv.split(X, y)):
    estimator = estimators[idx]

    # append subjects
    scores["train_subjects"].append(subjects[train_inds])
    scores["test_subjects"].append(subjects[test_inds])
    scores["test_y"].append(y[test_inds])
#     scores["test_y_encodings"].append(y_encode[test_inds])

    # evaluate on the test set
    y_train = y[train_inds]
    X_train = X[train_inds, :]
    y_pred_prob = estimator.predict_proba(X_train)[:, 1]
    print(y_pred_prob.shape)

    # compute calibration curve
    if len(np.unique(y)) == 2:
        fraction_of_positives, mean_predicted_value = calibration_curve(
            y_train, y_pred_prob, n_bins=10, strategy="quantile"
        )
        scores["train_fraction_pos"].append(fraction_of_positives)
        scores["train_mean_pred_value"].append(mean_predicted_value)

    # append training data
    scores["train_y_pred_proba"].append(y_pred_prob)

    # store ROC curve metrics on the held-out test set
    if len(np.unique(y)) == 2:
        fpr, tpr, thresholds = roc_curve(y_train, y_pred_prob, pos_label=1)
        fnr, tnr, neg_thresholds = roc_curve(y_train, y_pred_prob, pos_label=0)
        scores["train_fpr"].append(fpr)
        scores["train_tpr"].append(tpr)
        scores["train_fnr"].append(fnr)
        scores["train_tnr"].append(tnr)
        scores["train_thresholds"].append(thresholds)

    # evaluate on the test set
    y_test = y[test_inds]
    X_test = X[test_inds, :]
    y_pred_prob = estimator.predict_proba(X_test)
    y_pred_label = np.argmax(y_pred_prob, axis=1)
    y_pred_prob = y_pred_prob[:, 1]

    # compute calibration curve
    if len(np.unique(y)) == 2:
        fraction_of_positives, mean_predicted_value = calibration_curve(
            y_test, y_pred_prob, n_bins=10, strategy="quantile"
        )
        scores["test_fraction_pos"].append(fraction_of_positives)
        scores["test_mean_pred_value"].append(mean_predicted_value)
    
    # append testing data
    scores["test_y_pred_proba"].append(y_pred_prob)

    # store ROC curve metrics on the held-out test set
    if len(np.unique(y)) == 2:
        fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob, pos_label=1)
        fnr, tnr, neg_thresholds = roc_curve(y_test, y_pred_prob, pos_label=0)
        scores["test_fpr"].append(fpr)
        scores["test_tpr"].append(tpr)
        scores["test_fnr"].append(fnr)
        scores["test_tnr"].append(tnr)
        scores["test_thresholds"].append(thresholds)

    conf_matrix = confusion_matrix(
        y_test.astype(int), (y_pred_label).astype(int)
    )
    if len(np.unique(y)) == 2:
        tn, fp, fn, tp = conf_matrix.ravel()
        scores["test_specificity"].append(tn / (tn + fp))

    # get the permutation importances
    r = permutation_importance(
        estimator, X_test, y_test, n_repeats=5, random_state=random_state, n_jobs=-1,
        scoring='roc_auc_ovr'
    )
    scores["test_importances"].append(r.importances)
# Out:
# Using estimator  Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(n_jobs=-1, random_state=12345))])
# (80,)
# [0.29900618 0.44998563 0.56511292 0.63983984 0.69564021 0.73281072
#  0.76897528 0.79345658 0.82965377 0.86012288 0.96579128]
# [0.33417496 0.46450749 0.58066286 0.61865546 0.66930611 0.69068296
#  0.72531211 0.74458523 0.81997421 0.84834468 0.90525352]
# (80,)
# [0.34162992 0.51632802 0.59771861 0.66343058 0.69282471 0.72757584
#  0.75182477 0.78066973 0.79832924 0.82953765 0.88057182]
# [0.37500034 0.49571874 0.56776769 0.59165114 0.65602175 0.68758501
#  0.73777015 0.763062   0.7953365  0.83346799 0.94714282]
# (80,)
# [0.29005621 0.4929672  0.57097946 0.65418521 0.68369097 0.72773075
#  0.75812894 0.79452792 0.83733571 0.86291444 0.96771479]
# [0.36281719 0.42537905 0.5435418  0.60089042 0.63060617 0.70984079
#  0.73089674 0.78788762 0.82877735 0.83119104 0.91148493]
# (80,)
# [0.3479171  0.48972522 0.60965251 0.64810615 0.685236   0.7189213
#  0.74413218 0.78254205 0.82697219 0.85965311 0.95907916]
# [0.42492002 0.55270012 0.63099813 0.68399398 0.7237884  0.77375467
#  0.79792075 0.82322547 0.84120234 0.86579503 0.90468486]
# (80,)
# [0.34996876 0.4928295  0.56781803 0.66578022 0.70241184 0.73875448
#  0.77030439 0.78665706 0.81025776 0.84610375 0.90331252]
# [0.40847775 0.50456253 0.57382658 0.59436465 0.64024394 0.67781143
#  0.70093364 0.76921141 0.8140525  0.84585025 0.95861544]
# (80,)
# [0.39857341 0.5216514  0.58946335 0.63590343 0.68405294 0.71614359
#  0.74411273 0.78085036 0.81520023 0.84758983 0.95578923]
# [0.32834283 0.44449527 0.54898622 0.58120116 0.66535389 0.68703897
#  0.72483859 0.76920432 0.81308153 0.83265076 0.88893021]
# (80,)
# [0.31781248 0.44375703 0.56445225 0.60952957 0.68611988 0.73454923
#  0.77841706 0.8203077  0.84733783 0.87621986 0.9707063 ]
# [0.48527455 0.60274253 0.65551286 0.70229587 0.73193819 0.75796422
#  0.77079454 0.78989428 0.8352052  0.85769174 0.91440633]
# (80,)
# [0.31823586 0.45792363 0.58533623 0.67829965 0.70571974 0.73878646
#  0.75927061 0.79912106 0.82414154 0.85310432 0.96525907]
# [0.42279624 0.55547787 0.57648328 0.60938595 0.64426732 0.68940538
#  0.75035424 0.81988426 0.8348099  0.87956295 0.9066506 ]
# (80,)
# [0.36602638 0.49763279 0.59703595 0.63574506 0.68428339 0.72996162
#  0.75626697 0.78447659 0.82167934 0.84086299 0.95300462]
# [0.43734989 0.58852955 0.64284145 0.6876047  0.69978349 0.72925706
#  0.74256675 0.80923814 0.83192676 0.84775166 0.89247218]
# (80,)
# [0.45223277 0.53055964 0.60507202 0.64272204 0.69286365 0.71818733
#  0.74228526 0.76922203 0.79443498 0.82816461 0.88399229]
# [0.41417702 0.55202068 0.62763884 0.66357938 0.71009251 0.73810953
#  0.76662831 0.78688412 0.80229048 0.82625702 0.938576  ]
# (80,)
# [0.39464415 0.51244126 0.60082575 0.65070839 0.68960162 0.72105549
#  0.74373525 0.7852516  0.80963812 0.82903299 0.94280371]
# [0.47509415 0.60546788 0.63544747 0.68372175 0.71882066 0.72921041
#  0.74766184 0.77423015 0.80607264 0.85256255 0.87901906]
# (80,)
# [0.28516105 0.46925831 0.58335022 0.63645348 0.68741003 0.72825598
#  0.76444444 0.81069368 0.85911752 0.89220959 0.97262545]
# [0.26513177 0.49994841 0.5822085  0.65117675 0.69061488 0.73796205
#  0.77222962 0.83317295 0.8418156  0.86410937 0.91330466]
# (80,)
# [0.18183546 0.42416388 0.55218186 0.64052679 0.70050765 0.74821185
#  0.78536406 0.82987697 0.87038381 0.90310147 0.92646054]
# [0.25961146 0.37211607 0.44383419 0.58225946 0.63052139 0.66900254
#  0.72996726 0.81635824 0.87157729 0.9033265  0.98542155]
# (80,)
# [0.24577051 0.42384139 0.54049904 0.61608182 0.69699389 0.74310898
#  0.80181128 0.83226138 0.8540689  0.89151597 0.98213892]
# [0.3582236  0.41169878 0.52644359 0.61953048 0.68410562 0.7000283
#  0.75304152 0.78349166 0.82521805 0.85226754 0.94000928]
# (80,)
# [0.21464694 0.39102605 0.5225002  0.60792238 0.69136338 0.74963414
#  0.79319704 0.85561394 0.88782429 0.9076931  0.95158769]
# [0.34092932 0.61730383 0.65773833 0.69262956 0.74962285 0.77017673
#  0.80820315 0.84068952 0.88352462 0.91158655 0.98786256]
# (80,)
# [0.38354968 0.51570535 0.57016514 0.62287136 0.69080016 0.73166135
#  0.76179082 0.79057139 0.81589966 0.84005289 0.94870868]
# [0.44022829 0.60305115 0.62047818 0.66501959 0.69056161 0.72348478
#  0.73668538 0.74906933 0.80140368 0.82173802 0.88306166]
# (80,)
# [0.31853108 0.4650697  0.58195436 0.63842545 0.69442528 0.72506986
#  0.76279563 0.81126783 0.82382555 0.84261917 0.9604998 ]
# [0.39553328 0.48441617 0.5737977  0.59811136 0.65843477 0.68015457
#  0.71721771 0.74160786 0.77587967 0.85914544 0.9007454 ]
# (80,)
# [0.35990512 0.4798629  0.58079516 0.64898372 0.69473588 0.72702005
#  0.75014509 0.78602153 0.82327066 0.85676376 0.95349196]
# [0.52746847 0.60111409 0.65784586 0.68167401 0.70193256 0.72923983
#  0.77580143 0.81306287 0.8328564  0.85512096 0.87041969]
# (80,)
# [0.37837064 0.49750689 0.59574612 0.64185789 0.68366811 0.7159225
#  0.76456067 0.79049579 0.81475166 0.84379747 0.93259816]
# [0.46704065 0.55760644 0.60229275 0.64703962 0.69856736 0.72618244
#  0.74957349 0.79481396 0.80396453 0.83097645 0.89410151]
# (80,)
# [0.27804754 0.48145378 0.56753147 0.61390495 0.6787436  0.74157039
#  0.76193818 0.8093894  0.85446836 0.87213285 0.92390998]
# [0.24706004 0.37014436 0.52436014 0.62624978 0.69104574 0.74687858
#  0.77444501 0.8261027  0.85332061 0.90133683 0.97658738]

# %%
# add metadata
scores['y_classes'] = y_classes
scores['abnormal_fpaths'] = abnorm_bidspaths

# %% [markdown]
# ## Save Model Output Scores

# %%
exp_name = 'betaquantiles_jhhjeff_spikes'
fname = (
    deriv_root.parent
    / "derivatives"
    / f"cv{n_splits}_{clf_name}_mtry{max_features}_{exp_name}.json"
)
print(fname)
# Out:
# D:\OneDriveParent\OneDrive - Johns Hopkins\Shared Documents\bids\derivatives\cv20_lr_mtry5_betaquantiles_jhhjeff_spikes.json

# %%
with open(fname.with_suffix(".json"), "w") as fp:
    json.dump(scores, fp, cls=NumpyEncoder)
